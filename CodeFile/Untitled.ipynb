# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# 'git' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# 'git' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# 'git' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# 'git' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...

# %%
# %cd yolov5
# Out:
# C:\Users\Fantasy solution\SanYoloPy\yolov5

# %%
# %pip install -qr requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = torch.hub.load('ultralytics/yolov5','yolov5s')
# Out:
# Using cache found in C:\Users\Fantasy solution/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-11-17 Python-3.11.5 torch-2.1.0+cpu CPU
#
# ...
# 100%|██████████| 14.1M/14.1M [00:03<00:00, 3.89MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
img = "C:/Users/Fantasy solution/SanYoloPy/images.jfif"

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 191x263 1 person, 1 tie
# Speed: 80.0ms pre-process, 116.3ms inference, 17.0ms NMS per image at shape (1, 3, 480, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
# !python train.py --img 640 --batch 3 --epochs 2 --data '../../input/yamlfile/fire_data.yaml' --weights 'yolov5s.pt'
# Out:
# python: can't open file 'C:\\Users\\Fantasy solution\\SanYoloPy\\train.py': [Errno 2] No such file or directory

# %%
# %cd yolov5
# Out:
# C:\Users\Fantasy solution\SanYoloPy\yolov5

# %%
# !python train.py --img 640 --batch 3 --epochs 2 --data '../../input/yamlfile/fire_data.yaml' --weights 'yolov5s.pt'
# Out:
# train: weights='yolov5s.pt', cfg=, data='../../input/yamlfile/fire_data.yaml', hyp=data\hyps\hyp.scratch-low.yaml, epochs=2, batch_size=3, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data\hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5
# Traceback (most recent call last):
#   File "C:\Users\Fantasy solution\SanYoloPy\yolov5\train.py", line 771, in <module>
#     main(opt)
#   File "C:\Users\Fantasy solution\SanYoloPy\yolov5\train.py", line 533, in main
# ...

# %%
# !python train.py --img 640 --batch 3 --epochs 2 --data 'fire_data.yaml' --weights 'yolov5s.pt'
# Out:
# train: weights='yolov5s.pt', cfg=, data='fire_data.yaml', hyp=data\hyps\hyp.scratch-low.yaml, epochs=2, batch_size=3, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data\hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5
# Traceback (most recent call last):
#   File "C:\Users\Fantasy solution\SanYoloPy\yolov5\train.py", line 771, in <module>
#     main(opt)
#   File "C:\Users\Fantasy solution\SanYoloPy\yolov5\train.py", line 533, in main
# ...

# %%
# %cd yolov5
# Out:
# C:\Users\Fantasy solution\SanYoloPy\yolov5

# %%
# !python train.py --img 640 --batch 3 --epochs 2 --data 'fire_data.yaml' --weights 'yolov5s.pt'
# Out:
# train: weights='yolov5s.pt', cfg=, data='fire_data.yaml', hyp=data\hyps\hyp.scratch-low.yaml, epochs=2, batch_size=3, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data\hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5
# Traceback (most recent call last):
#   File "C:\Users\Fantasy solution\SanYoloPy\yolov5\train.py", line 771, in <module>
#     main(opt)
#   File "C:\Users\Fantasy solution\SanYoloPy\yolov5\train.py", line 533, in main
# ...

# %%
# !python train.py --img 640 --batch 3 --epochs 2 --data '..\yolov5\fire_data.yaml' --weights 'yolov5s.pt'
# Out:
# usage: train.py [-h] [--weights WEIGHTS] [--cfg CFG] [--data DATA] [--hyp HYP]
#                 [--epochs EPOCHS] [--batch-size BATCH_SIZE] [--imgsz IMGSZ]
#                 [--rect] [--resume [RESUME]] [--nosave] [--noval]
#                 [--noautoanchor] [--noplots] [--evolve [EVOLVE]]
#                 [--evolve_population EVOLVE_POPULATION]
#                 [--resume_evolve RESUME_EVOLVE] [--bucket BUCKET]
#                 [--cache [CACHE]] [--image-weights] [--device DEVICE]
#                 [--multi-scale] [--single-cls] [--optimizer {SGD,Adam,AdamW}]
#                 [--sync-bn] [--workers WORKERS] [--project PROJECT]
#                 [--name NAME] [--exist-ok] [--quad] [--cos-lr]
#                 [--label-smoothing LABEL_SMOOTHING] [--patience PATIENCE]
#                 [--freeze FREEZE [FREEZE ...]] [--save-period SAVE_PERIOD]
#                 [--seed SEED] [--local_rank LOCAL_RANK] [--entity ENTITY]
#                 [--upload_dataset [UPLOAD_DATASET]]
# ...

# %%
# !python train.py --img 640 --batch 3 --epochs 2 --data '..\yolov5\fire_data.yaml' --weights 'yolov5s.pt'
# Out:
# train: weights='yolov5s.pt', cfg=, data='..\yolov5\fire_data.yaml', hyp=data\hyps\hyp.scratch-low.yaml, epochs=2, batch_size=3, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data\hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5
# Traceback (most recent call last):
#   File "C:\Users\Fantasy solution\SanYoloPy\yolov5\train.py", line 771, in <module>
#     main(opt)
#   File "C:\Users\Fantasy solution\SanYoloPy\yolov5\train.py", line 533, in main
# ...

# %%
# %cd yolov5
# Out:
# [WinError 2] The system cannot find the file specified: 'yolov5'
# C:\Users\Fantasy solution\SanYoloPy\yolov5

# %%
# !python train.py --img 640 --batch 3 --epochs 2 --data "fire_data.yaml" --weights 'yolov5s.pt'
# Out:
# train: weights='yolov5s.pt', cfg=, data=fire_data.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=2, batch_size=3, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data\hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5
# fatal: cannot change to 'C:\Users\Fantasy': No such file or directory
# YOLOv5  2024-1-4 Python-3.11.5 torch-2.1.0+cpu CPU
#
# ...

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='runs/train/exp4/weights/best.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\Fantasy solution/.cache\torch\hub\master.zip
# YOLOv5  2024-1-4 Python-3.11.5 torch-2.1.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
img = "C:/Users/Fantasy solution/SanYoloPy/yolov5/ffdata/Fire_data/images/train/fire.104.png"

# %%
results = model(img)
print(results)
# Out:
# image 1/1: 282x500 3 Fires
# Speed: 13.9ms pre-process, 135.0ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()
